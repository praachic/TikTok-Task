# %% [markdown]
# # [Project Title]
#
# **Author:**
# **Date:**
#
# Short 1–2 sentence summary of what this notebook is about.

# %% [markdown]
# ## 1. Video URL and Description
#
# **Video URL:**
# <insert link here>
#
# **Brief Description (3–5 sentences):**
# - What is shown in the video?
# - Who is speaking / what context?
# - Why did you choose this video for your project?

# %% [markdown]
# ## 2. Research Question
#
# Write your clearly scoped research question here.
#
# **Example format:**
# > To what extent does [LLM/model/prompting strategy X] improve [outcome, e.g., inter-rater reliability, agreement with rubric, etc.] on [specific task]?
#
# You can also add:
# - **Hypothesis:** What do you expect to happen and why?

# %% [markdown]
# ## 3. Concepts and How They Changed with Coding
#
# Describe the key concepts you used in this project (e.g., sentiment, argument strength, politeness, confusion, relevance, etc.) and how your understanding of them evolved once you started coding and working with data.
#
# You can use a table like this:
#
# | Concept | Initial Definition | Operationalization in Code | How it Changed After Coding |
# |--------|---------------------|----------------------------|------------------------------|
# | [Concept 1] | [Your initial idea] | [How you turned it into labels/rules/prompts] | [What you realized after seeing real data] |
# | [Concept 2] | ... | ... | ... |
#
# Or write in paragraph style:
# - **Concept 1:** description + how coding changed your understanding
# - **Concept 2:** description + how coding changed your understanding

# %%
## 4. Final LLM Prompt and Inter-Rater Reliability Scores

### 4.1 Final LLM Prompt

Paste your final (best) prompt here:

```text
[PASTE YOUR FINAL PROMPT EXACTLY AS USED]
